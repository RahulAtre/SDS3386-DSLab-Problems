# %% [markdown]
# # SDS 3386 Assignment 2 - Data Wrangling
#
# 2023 Fall, Rahul Atre
#
# Total Marks: 10

# %% [markdown]
# # Question 1 (1 mark)
#
# Using the basketball dataset here: https://github.com/fivethirtyeight/data/raw/master/nba-elo/nbaallelo.csv (and described here: https://github.com/fivethirtyeight/data/tree/master/nba-elo), determine the proportion of Home games ('game_location' == 'H') won, and the proportion of Away games won, in the entire dataset.
#
# *Hint: `df.value_counts?`*

# %%
import pandas as pd

data = pd.read_csv("https://github.com/fivethirtyeight/data/raw/master/nba-elo/nbaallelo.csv")

home = data.value_counts(data["game_location"])['H']
away = data.value_counts(data["game_location"])["A"]

df1 = data.loc[data['game_location'] == 'H']
df2 = data.loc[data['game_location'] == 'A']

homeWins = data.value_counts(df1["game_result"])["W"]
awayWins = data.value_counts(df2["game_result"])["W"]

percentHomeWins = (homeWins/home)*100
percentAwayWins = (awayWins/away)*100

print("The proportion of Home games won is " + str(percentHomeWins) + "%, and the proportion of Away games won is "+ str(percentAwayWins) + "%.")
# Out:
# The proportion of Home games won is 62.252526212423575%, and the proportion of Away games won is 37.74747378757642%.

# %% [markdown]
# # Question 2 (3 marks)
#
# Use the dataset `grades.csv` provided with this assignment. The grading policy for the course is:
#
#     10% for each assignment and 60% for the final exam.
#
# A) [1 point] Add a new column 'Final', calculated according to the above formula. Put 'INC' (for incomplete) for the student who didn't write the exam. Save the data to a file 'grades_calculated.csv', *without* an initial column containing row numbers (i.e. indexes).
#
# *Hint: 'df.to_csv?'*
#
# B) [2 points] Make a single chart showing all students' grades for all 5 assessments, with the assessment name on the horizontal axis and percentage grades on the vertical axis, and a legend listing the students. Choose a chart type that makes it easy to visually group the grades for a particular student and follow their progress over time.
#
# *Hints: Tidy the data. Convert all grades to percentages.*

# %%
import pandas as pd
import altair as alt


grades_df = pd.read_csv('grades.csv')

#Part a: 
out_of = grades_df.loc[0]

grades_df[['Asst1','Asst2','Asst3','Asst4']] = grades_df[['Asst1','Asst2','Asst3','Asst4']].fillna(0)

grades_df['Final'] = (grades_df['Asst1']/out_of['Asst1'] * 0.10 + grades_df['Asst2']/out_of['Asst2'] * 0.10 + grades_df['Asst3']/out_of['Asst3'] * 0.10 + grades_df['Asst4']/out_of['Asst4'] * 0.10 + grades_df['Exam']/out_of['Exam'] * 0.60) * 100
grades_df['Final'] = grades_df['Final'].fillna('INC')

grades_df = grades_df[:-1] # Removing mean row from grades_df

grades_df.to_csv("grades_calculated.csv", index = False)


#Part b: 

grades_df[['Asst1', 'Asst2', 'Asst3', 'Asst4', 'Exam']] = grades_df[['Asst1', 'Asst2', 'Asst3', 'Asst4', 'Exam']] / out_of[['Asst1', 'Asst2', 'Asst3', 'Asst4', 'Exam']] * 100

grades_df2 = grades_df.drop(0)

newdf = pd.melt(grades_df2, id_vars = 'Name', value_vars = ['Asst1', 'Asst2', 'Asst3', 'Asst4', 'Exam'], var_name = 'Assignment', value_name = 'Percentage')

student_report = alt.Chart(newdf, title = "Assessment Grades").mark_bar().encode(
    x = alt.X("Assignment:O", title = "Assessment"),
    y = alt.Y("Percentage:Q", title = "Percentage Grade"),
    color = alt.Color("Name:N", title = "Student Name"),
    facet = alt.Facet("Name:N", title = None)
)

display(grades_df) # Part a
display(student_report) # Part b
# Out:
#        Name  Asst1  Asst2  Asst3  Asst4   Exam  Unnamed: 6  Final
# 0  (Out of)  100.0  100.0  100.0  100.0  100.0       100.0  100.0
# 1      Adam   90.0   80.0   80.0   60.0   60.0        67.0   67.0
# 2      Bing   70.0   80.0   70.0   90.0   75.0        76.0   76.0
# 3     Carla   60.0    0.0   50.0    0.0    NaN        11.0    INC
# 4    Darius   60.0   70.0  100.0    0.0   80.0        71.0   71.0
# 5     Ellen   80.0   80.0    0.0   90.0   92.0        80.2   80.2
# alt.Chart(...)

# %% [markdown]
# # Question 3 (3 marks)
#
# This question uses a subset of the Billboard Top 100 dataset, provided with this assignment in `billboardhw.csv`.
#
#
# A) Select all songs that first appeared on the charts in January 2000. (The date of first appearance is 'date_entered'.)
#
# *Hint: `pd.to_datetime()`*
#
# B) Partially tidy this chart, by putting all rankings (for all weeks) in one column named 'ranking'.
#
# C) Produce a single graphic showing, for each song in the chart, a line graph of ranking versus time (week).

# %% [markdown]
# ## A)

# %%
billboard_df = pd.read_csv("./billboardhw.csv")

billboard_df['date.entered'] = pd.to_datetime(billboard_df['date.entered'])

filter = billboard_df[(billboard_df['date.entered'].dt.year == 2000) & (billboard_df['date.entered'].dt.month == 1)]

filter
# Out:
#      year       artist.inverted                                track  time  \
# 12   2000      Vertical Horizon                  Everything You Want  4:01
# 25   2000                 Sisqo                           Thong Song  4:05
# 28   2000                   Joe                         I Wanna Know  4:57
# 30   2000                N'Sync                          Bye Bye Bye  3:15
# 39   2000  Backstreet Boys, The  Show Me The Meaning Of Being Lonely  3:54
# 50   2000               Sonique                     It Feels So Good  3:48
# 63   2000       Spears, Britney   From The Bottom Of My Broken Heart  4:30
# 64   2000       Third Eye Blind                     Never Let You Go  3:57
# 96   2000                Sammie                            I Like It  4:09
# 99   2000               Dr. Dre                     Forgot About Dre  3:42
# 100  2000              D'Angelo          Untitled (How Does It Feel)  7:10
# 116  2000             Sugar Ray                          Falls Apart  4:15
# 122  2000           Keith, Toby             How Do You Like Me Now?!  3:29
# 123  2000        Strait, George                         The Best Day  3:24
# 134  2000                   Eve                        Love Is Blind  3:51
# 135  2000               Aaliyah                        I Don't Wanna  4:15
# 140  2000           Wills, Mark                          Back At One  4:00
# 151  2000       Lawrence, Tracy                      Lessons Learned  2:55
# 168  2000        Eastsidaz, The                               G'D Up  4:27
# 187  2000       Messina, Jo Dee                  Because You Love Me  3:50
# 226  2000                 Jay-Z        Do It Again (Put Ya Hands Up)  3:47
# 230  2000                   DMX                       What's My Name  3:50
# 243  2000                 Q-Tip                     Breathe And Stop  4:06
# 255  2000             Bega, Lou                       Tricky Tricky   3:23
# 260  2000           Brock, Chad            A Country Boy Can Survive  3:54
# 262  2000           Byrd, Tracy                Put Your Hand In Mine  4:30
# 268  2000           Allan, Gary              Smoke Rings In The Dark  4:18
# 269  2000              Ginuwine                The Best Man I Can Be  4:06
# 296  2000           Diffie, Joe                    The Quittin' Kind  3:23
#
#        genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 12      Rock   2000-01-22  2000-07-15         70       61.0       53.0  ...
# 25      Rock   2000-01-29  2000-05-20         74       63.0       35.0  ...
# 28      Rock   2000-01-01  2000-07-01         94       86.0       69.0  ...
# 30      Rock   2000-01-29  2000-04-15         42       20.0       19.0  ...
# 39      Rock   2000-01-01  2000-03-18         74       62.0       55.0  ...
# 50      Rock   2000-01-22  2000-04-22         67       52.0       30.0  ...
# 63      Rock   2000-01-29  2000-02-26         76       59.0       52.0  ...
# 64      Rock   2000-01-22  2000-04-01         65       32.0       25.0  ...
# 96      Rock   2000-01-29  2000-04-15         85       68.0       58.0  ...
# 99       Rap   2000-01-22  2000-03-25         75       55.0       47.0  ...
# 100      R&B   2000-01-22  2000-02-19         77       56.0       35.0  ...
# 116     Rock   2000-01-15  2000-02-19         70       64.0       54.0  ...
# 122  Country   2000-01-29  2000-04-08         77       72.0       59.0  ...
# 123  Country   2000-01-29  2000-04-22         73       64.0       54.0  ...
# 134      Rap   2000-01-08  2000-02-19         94       91.0       57.0  ...
# 135     Rock   2000-01-29  2000-03-04         84       62.0       51.0  ...
# 140  Country   2000-01-15  2000-02-26         89       55.0       51.0  ...
# 151  Country   2000-01-29  2000-04-08         80       73.0       61.0  ...
# 168      Rap   2000-01-08  2000-02-12         77       77.0       89.0  ...
# 187  Country   2000-01-29  2000-03-11         83       78.0       71.0  ...
# 226      Rap   2000-01-15  2000-01-29         95       68.0       65.0  ...
# 230      Rap   2000-01-15  2000-02-12         98       76.0       69.0  ...
# 243     Rock   2000-01-22  2000-01-22         71       71.0       81.0  ...
# 255     Rock   2000-01-29  2000-02-05         75       74.0       87.0  ...
# 260  Country   2000-01-01  2000-01-08         93       75.0       92.0  ...
# 262  Country   2000-01-29  2000-02-12         81       77.0       76.0  ...
# 268  Country   2000-01-22  2000-02-05         80       78.0       76.0  ...
# 269     Rock   2000-01-08  2000-03-04         97       97.0       83.0  ...
# 296  Country   2000-01-01  2000-01-22         98      100.0      100.0  ...
#
#      x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 12          NaN         NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN         NaN
# 28          NaN         NaN         NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN         NaN         NaN
# 39          NaN         NaN         NaN         NaN         NaN         NaN
# 50          NaN         NaN         NaN         NaN         NaN         NaN
# 63          NaN         NaN         NaN         NaN         NaN         NaN
# 64          NaN         NaN         NaN         NaN         NaN         NaN
# 96          NaN         NaN         NaN         NaN         NaN         NaN
# 99          NaN         NaN         NaN         NaN         NaN         NaN
# 100         NaN         NaN         NaN         NaN         NaN         NaN
# 116         NaN         NaN         NaN         NaN         NaN         NaN
# 122         NaN         NaN         NaN         NaN         NaN         NaN
# 123         NaN         NaN         NaN         NaN         NaN         NaN
# 134         NaN         NaN         NaN         NaN         NaN         NaN
# 135         NaN         NaN         NaN         NaN         NaN         NaN
# 140         NaN         NaN         NaN         NaN         NaN         NaN
# 151         NaN         NaN         NaN         NaN         NaN         NaN
# 168         NaN         NaN         NaN         NaN         NaN         NaN
# 187         NaN         NaN         NaN         NaN         NaN         NaN
# 226         NaN         NaN         NaN         NaN         NaN         NaN
# 230         NaN         NaN         NaN         NaN         NaN         NaN
# 243         NaN         NaN         NaN         NaN         NaN         NaN
# 255         NaN         NaN         NaN         NaN         NaN         NaN
# 260         NaN         NaN         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN         NaN         NaN
# 268         NaN         NaN         NaN         NaN         NaN         NaN
# 269         NaN         NaN         NaN         NaN         NaN         NaN
# 296         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x73rd.week  x74th.week  x75th.week  x76th.week
# 12          NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN
# 28          NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN
# 39          NaN         NaN         NaN         NaN
# 50          NaN         NaN         NaN         NaN
# 63          NaN         NaN         NaN         NaN
# 64          NaN         NaN         NaN         NaN
# 96          NaN         NaN         NaN         NaN
# 99          NaN         NaN         NaN         NaN
# 100         NaN         NaN         NaN         NaN
# 116         NaN         NaN         NaN         NaN
# 122         NaN         NaN         NaN         NaN
# 123         NaN         NaN         NaN         NaN
# 134         NaN         NaN         NaN         NaN
# 135         NaN         NaN         NaN         NaN
# 140         NaN         NaN         NaN         NaN
# 151         NaN         NaN         NaN         NaN
# 168         NaN         NaN         NaN         NaN
# 187         NaN         NaN         NaN         NaN
# 226         NaN         NaN         NaN         NaN
# 230         NaN         NaN         NaN         NaN
# 243         NaN         NaN         NaN         NaN
# 255         NaN         NaN         NaN         NaN
# 260         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN
# 268         NaN         NaN         NaN         NaN
# 269         NaN         NaN         NaN         NaN
# 296         NaN         NaN         NaN         NaN
#
# [29 rows x 83 columns]

# %% [markdown]
# ## B)

# %%
import re 
ranking_columns = [col for col in filter.columns if re.match(r'x\d+(st|nd|rd|th).week', col)]
pd.options.display.max_rows = 500

df = pd.melt(filter, id_vars=['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered', 'date.peaked'],
             value_vars=ranking_columns, var_name='week', value_name='ranking')

df.dropna(subset=['ranking'], inplace=True)

# Print the resulting DataFrame

df['week'] = df['week'].str.extract(r'(\d+)').astype(int)


df.sort_values(by=['year', 'artist.inverted', 'track', 'week'], inplace=True)

# Reset the index
df.reset_index(drop=True, inplace=True)


df.head(70)
# Out:
#     year       artist.inverted                                track  time  \
# 0   2000               Aaliyah                        I Don't Wanna  4:15
# 1   2000               Aaliyah                        I Don't Wanna  4:15
# 2   2000               Aaliyah                        I Don't Wanna  4:15
# 3   2000               Aaliyah                        I Don't Wanna  4:15
# 4   2000               Aaliyah                        I Don't Wanna  4:15
# 5   2000               Aaliyah                        I Don't Wanna  4:15
# 6   2000               Aaliyah                        I Don't Wanna  4:15
# 7   2000               Aaliyah                        I Don't Wanna  4:15
# 8   2000               Aaliyah                        I Don't Wanna  4:15
# 9   2000               Aaliyah                        I Don't Wanna  4:15
# 10  2000               Aaliyah                        I Don't Wanna  4:15
# 11  2000               Aaliyah                        I Don't Wanna  4:15
# 12  2000               Aaliyah                        I Don't Wanna  4:15
# 13  2000               Aaliyah                        I Don't Wanna  4:15
# 43     Rock   2000-01-01  2000-03-18    19     23.0
# 44     Rock   2000-01-01  2000-03-18    20     26.0
# 45     Rock   2000-01-01  2000-03-18    21     32.0
# 46     Rock   2000-01-01  2000-03-18    22     34.0
# 47     Rock   2000-01-01  2000-03-18    23     45.0
# 48     Rock   2000-01-01  2000-03-18    24     47.0
# 49     Rock   2000-01-29  2000-02-05     1     75.0
# 50     Rock   2000-01-29  2000-02-05     2     74.0
# 51     Rock   2000-01-29  2000-02-05     3     87.0
# 52  Country   2000-01-01  2000-01-08     1     93.0
# 53  Country   2000-01-01  2000-01-08     2     75.0
# 54  Country   2000-01-01  2000-01-08     3     92.0
# 55  Country   2000-01-29  2000-02-12     1     81.0
# 56  Country   2000-01-29  2000-02-12     2     77.0
# 57  Country   2000-01-29  2000-02-12     3     76.0
# 58  Country   2000-01-29  2000-02-12     4     76.0
# 59  Country   2000-01-29  2000-02-12     5     86.0
# 60  Country   2000-01-29  2000-02-12     6     88.0
# 61  Country   2000-01-29  2000-02-12     7     92.0
# 62  Country   2000-01-29  2000-02-12     8     99.0
# 63      R&B   2000-01-22  2000-02-19     1     77.0
# 64      R&B   2000-01-22  2000-02-19     2     56.0
# 65      R&B   2000-01-22  2000-02-19     3     35.0
# 66      R&B   2000-01-22  2000-02-19     4     26.0
# 67      R&B   2000-01-22  2000-02-19     5     25.0
# 68      R&B   2000-01-22  2000-02-19     6     25.0
# 69      R&B   2000-01-22  2000-02-19     7     28.0

# %% [markdown]
# ## C)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

for name, group in df.groupby(['track']):
    plt.plot(group['week'], group['ranking'], label=name)


plt.xlabel('Week')
plt.ylabel('Ranking')
plt.title('Ranking versus Time for Songs')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))
plt.grid(True)

# %% [markdown]
# # Question 4 (3 marks)
#
# For this question you will need:
#
# 1) The `geopandas` package (install it using conda).
#
# *Note that geopandas is built on top of pandas, so you can use pandas operations.*
#
# 2) A shapefile for Canadian provinces. To get this, go to <https://library.carleton.ca/find/gis/geospatial-data/shapefiles-canada-united-states-and-world> and then:
#
#     - click "Statistics Canada 2021 cartographic boundary shapefile of provinces/territories"
#     - select Type "Digital Boundary Files (DBF)"
#     - select "Administrative boundaries"-> "Provinces/territories"
#     - select "Format"->"Shapefile (.shp)"
#
# Then "Continue" and download the zip file. Unzip it and move the whole folder to your working directory.
#
# 3) Some per-province employment data to display. Download the data from here: <https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1410006601>
#
# Unzip it and move the whole folder to your working directory.
#
#
# A) Run the following cells. Then select only the rows corresponding to the 10 provinces, and plot that.

# %%
import pandas as pd
import geopandas as gpd

# %%
provterr = gpd.read_file('lpr_000a21a_e/lpr_000a21a_e.shp')
provterr.plot()
provs = provterr.loc[:9]
provs.plot()
# Out:
# <Axes: >

# %% [markdown]
# B) Load the employment data into a Pandas dataframe.
#
# Select only rows from 2021, with:
#
# - 'Sex' == 'Both sexes'
#
# - 'Age group' == '15 years and over'
#
# - 'Wages' == 'Total employees, all wages'
#
# - 'Job permanency' and 'Union coverage' both starting with 'Total'
#     (hint: `.str.startswith('Total')`)
#
# Select only the column containing the province names and the 'VALUE' column, which in this case is the total number of employees, in thousands.
#
# Join this data to the geopandas dataframe you created in (A).

# %%
employment_df = pd.read_csv('14100066.csv')


employment_df = employment_df[(employment_df['REF_DATE'] == 2021) & 
              (employment_df['Sex'] == 'Both sexes') &
              (employment_df['Age group'] == '15 years and over') &
              (employment_df['Wages'] == 'Total employees, all wages') & 
              (employment_df['Job permanency'].str.startswith('Total')) &
              (employment_df['Union coverage'].str.startswith('Total'))]

employment_df = employment_df[["GEO", "VALUE"]]

employment_df = employment_df.rename(columns={"GEO":"PRENAME"})


prov = pd.merge(provs, employment_df, how="inner", on="PRENAME")

gprov = gpd.GeoDataFrame(prov)

gprov
# Out:
#   PRUID        DGUID                                             PRNAME  \
# 0    10  2021A000210  Newfoundland and Labrador / Terre-Neuve-et-Lab...
# 1    11  2021A000211       Prince Edward Island / Île-du-Prince-Édouard
# 2    12  2021A000212                      Nova Scotia / Nouvelle-Écosse
# 3    13  2021A000213                  New Brunswick / Nouveau-Brunswick
# 4    24  2021A000224                                    Quebec / Québec
# 5    35  2021A000235                                            Ontario
# 6    46  2021A000246                                           Manitoba
# 7    47  2021A000247                                       Saskatchewan
# 8    48  2021A000248                                            Alberta
# 9    59  2021A000259            British Columbia / Colombie-Britannique
#
#                      PRENAME                  PRFNAME PREABBR   PRFABBR  \
# 0  Newfoundland and Labrador  Terre-Neuve-et-Labrador    N.L.  T.-N.-L.
# 1       Prince Edward Island    Île-du-Prince-Édouard  P.E.I.  Î.-P.-É.
# 2                Nova Scotia          Nouvelle-Écosse    N.S.     N.-É.
# 3              New Brunswick        Nouveau-Brunswick    N.B.     N.-B.
# 4                     Quebec                   Québec    Que.        Qc
# 5                    Ontario                  Ontario    Ont.      Ont.
# 6                   Manitoba                 Manitoba    Man.      Man.
# 7               Saskatchewan             Saskatchewan   Sask.     Sask.
# 8                    Alberta                  Alberta   Alta.      Alb.
# 9           British Columbia     Colombie-Britannique    B.C.     C.-B.
#
#        LANDAREA                                           geometry   VALUE
# 0  3.581704e+05  POLYGON ((7644464.869 2980078.217, 7648864.423...   205.3
# 1  5.681179e+03  POLYGON ((8427184.671 1638777.314, 8427169.677...    69.0
# 2  5.282471e+04  MULTIPOLYGON (((8693947.526 1494906.237, 86935...   411.1
# 3  7.124850e+04  POLYGON ((8188457.820 1707919.583, 8188444.194...   325.7
# 4  1.298600e+06  MULTIPOLYGON (((8396476.571 1754341.151, 83956...  3764.6
# 5  8.924118e+05  POLYGON ((6378273.940 2296884.400, 6378455.637...  6305.5
# 6  5.403102e+05  POLYGON ((6039718.643 2636909.880, 6039717.720...   574.6
# 7  5.770604e+05  POLYGON ((5248633.914 2767057.263, 5249285.640...   477.1
# 8  6.346583e+05  POLYGON ((5228304.177 2767597.891, 5228098.463...  1915.1
# 9  9.206866e+05  POLYGON ((4018904.414 3410247.271, 4019429.869...  2243.3

# %% [markdown]
# C) Create a *choropleth* chart showing the total employment in each province, i.e. a map with provinces coloured according to the 'VALUE' column, with a legend.
#
# *Hint:`prov.plot?`*

# %%
gprov.plot(column = 'VALUE', figsize = (15,12), edgecolor = 'black', legend = True)
# Out:
# <Axes: >
